# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_dropped = df.dropna(axis=1,thresh=800)

# %%
df_dropped
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.groupby('Survived').describe()['Age'].T
# Out:
# Survived           0           1
# count     424.000000  290.000000
# mean       30.626179   28.343690
# std        14.172110   14.950952
# min         1.000000    0.420000
# 25%        21.000000   19.000000
# 50%        28.000000   28.000000
# 75%        39.000000   36.000000
# max        74.000000   80.000000

# %%
df2 = pd.read_csv('bank/bank.csv',sep=";")

# %%
df2.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df2_grouped = df2.groupby('education')

# %%
df2_primary=df2_grouped.get_group('primary')
df2_primary = df2_primary.head()[['age','job','marital']]
df2_secondary=df2_grouped.get_group('secondary')
df2_secondary=df2_secondary.head()[['age','job','marital']]

# %%
df2_primary
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2_secondary
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
df_test = pd.concat([df2_primary,df2_secondary],axis=1)
df_test
# Out:
#      age          job   marital   age          job  marital
# 0   30.0   unemployed   married   NaN          NaN      NaN
# 1    NaN          NaN       NaN  33.0     services  married
# 4    NaN          NaN       NaN  59.0  blue-collar  married
# 7    NaN          NaN       NaN  39.0   technician  married
# 9   43.0     services   married   NaN          NaN      NaN
# 10   NaN          NaN       NaN  39.0     services  married
# 11   NaN          NaN       NaN  43.0       admin.  married
# 18  25.0  blue-collar    single   NaN          NaN      NaN
# 26  55.0  blue-collar   married   NaN          NaN      NaN
# 36  78.0      retired  divorced   NaN          NaN      NaN

# %%
df_test.iloc[[8,9],[3,4]]
# Out:
#     age  job
# 26  NaN  NaN
# 36  NaN  NaN

# %%
df_test.loc[[9,10],'age']
# Out:
#      age   age
# 9   43.0   NaN
# 10   NaN  39.0

# %%
df2_primary
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2_primary.loc[[9,18],['job','marital']]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2_primary.iloc[[1,2],[1,2]]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2_primary.loc[[9,18],['age','marital']]
# Out:
#     age  marital
# 9    43  married
# 18   25   single

# %%
import pandas as pd

# %%
df = pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(df)
# Out:
# list

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df[0].dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
df[0][['Player','Age']]
# Out:
#              Player Age
# 0        Quincy Acy  24
# 1      Jordan Adams  20
# 2      Steven Adams  21
# 3       Jeff Adrien  28
# 4     Arron Afflalo  29
# ..              ...  ..
# 670  Thaddeus Young  26
# 671  Thaddeus Young  26
# 672  Thaddeus Young  26
# 673     Cody Zeller  22
# 674    Tyler Zeller  25
#
# [675 rows x 2 columns]

# %%
df1 = df[0]

# %%
df1.to_csv('NBA.csv',index=False,header=False)

# %%
l = pd.read_html('https://stats.espncricinfo.com/ci/engine/records/averages/batting.html?class=3;id=6;type=team')

# %%
len(l)
# Out:
# 3

# %%
l[0]
# Out:
#                Player       Span  Mat Inns NO  Runs   HS    Ave   BF      SR  \
# 0          AB Agarkar  2006-2007    4    2  0    15   14   7.50   11  136.36
# 1            KK Ahmed  2018-2019   14    1  1     1   1*      -    1  100.00
# 2           S Aravind  2015-2015    1    -  -     -    -      -    -       -
# 3            R Ashwin  2010-2021   51   11  7   123  31*  30.75  115  106.95
# 4          Avesh Khan  2022-2022    1    -  -     -    -      -    -       -
# ..                ...        ...  ...  ... ..   ...  ...    ...  ...     ...
# 92      R Vinay Kumar  2010-2013    9    1  1     2   2*      -    4   50.00
# 93  Washington Sundar  2017-2021   31   11  4    47  14*   6.71   32  146.87
# 94           SA Yadav  2021-2022   14   12  3   351   65  39.00  212  165.56
# 95           UT Yadav  2012-2019    7    1  0     2    2   2.00    4   50.00
# 96       Yuvraj Singh  2007-2017   58   51  9  1177  77*  28.02  863  136.38
#
#    100 50  0  4s  6s
# 0    0  0  0   2   0
# ...

# %%
l[1]
# Out:
#                                                    0
# 0  By default, the shading indicates records from...
# 1  Adjust:  most recent  | past week  | past mont...

# %%
l[2]
# Out:
#                                                    0
# 0  Records includes the following current or rece...
# 1  India v Sri Lanka at Dharamsala, 2nd T20I, Feb...
# 2  India v Sri Lanka at Lucknow, 1st T20I, Feb 24...
# 3  India v West Indies at Kolkata, 3rd T20I, Feb ...

# %%
l[0].to_csv('cric.csv')

# %%
d = """
{
"name": "shreyas",
"email id": "shreyasbanagar7@gmail.com",
"tech": ["ML", "DL", "NLP", "CV","RL"]
}
"""

# %%
import json

# %%
res = json.loads(d)

# %%
res
# Out:
# {'name': 'shreyas',
#  'email id': 'shreyasbanagar7@gmail.com',
#  'tech': ['ML', 'DL', 'NLP', 'CV', 'RL']}

# %%
pd.DataFrame(res)
# Out:
#       name                   email id tech
# 0  shreyas  shreyasbanagar7@gmail.com   ML
# 1  shreyas  shreyasbanagar7@gmail.com   DL
# 2  shreyas  shreyasbanagar7@gmail.com  NLP
# 3  shreyas  shreyasbanagar7@gmail.com   CV
# 4  shreyas  shreyasbanagar7@gmail.com   RL

# %%
pd.read_json(res)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SHREYA~1.BAN\AppData\Local\Temp/ipykernel_4572/464885364.py in <module>
# ----> 1 pd.read_json(res)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SHREYA~1.BAN\AppData\Local\Temp/ipykernel_26276/2278676361.py in <module>
#      29       "received_events_url": "https://api.github.com/users/mroeschke/received_events",
#      30       "type": "User",
# ---> 31       "site_admin": false
#      32     },
#      33     "labels": [
#
# NameError: name 'false' is not defined

# %%
data2 = 'https://api.github.com/repos/pandas-dev/pandas/issues'

# %%
df = pd.DataFrame(data2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SHREYA~1.BAN\AppData\Local\Temp/ipykernel_26276/687840827.py in <module>
# ----> 1 df = pd.DataFrame(data2)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
df2 = pd.DataFrame(data2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SHREYA~1.BAN\AppData\Local\Temp/ipykernel_26276/2339997996.py in <module>
# ----> 1 df2 = pd.DataFrame(data2)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
df2
# Out:
#                           packetType  \
# checkEngineLightFlag               D
# batteryVoltageStableTime           D
# batteryVoltageStable               D
# batteryVoltageOff                  D
# batteryCrankParamTN                D
# batteryCrankParamVN                D
# batteryCrankParamTP                D
# batteryCrankParamVP                D
# batteryCrankParamTT                D
# batteryCrankParamV0                D
# batteryVoltageMaxOn                D
# batteryVoltageMinOn                D
# batteryVoltageMaxOff               D
# batteryVoltageMinOff               D
# batteryVoltageOnAverage            D
# engineLoadMax                      D
# engineLoadAverage                  D
# rpmMax                             D
# rpmAverage                         D
# gpsSpeedAverage                    D
# vssMax                             D
# vssAverage                         D
# tcuTemperatureMin                  D
# tcuTemperatureMax                  D
# ...

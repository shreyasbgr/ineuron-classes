# %%
import pandas as pd

# %%
pd.read_csv('sample.csv')
# Out:
#       Name                            Email    Location
# 0  Shreyas        shreyasbanagar7@gmail.com       Thane
# 1  Navneet  navneetravichandran13@gmail.com  Coimbatore
# 2   Daniel          danieparera15@gmail.com       Thane

# %%
pd.read_csv('sample.csv', names=['Col1','Col2','Col3'])
# Out:
#       Col1                             Col2        Col3
# 0     Name                            Email    Location
# 1  Shreyas        shreyasbanagar7@gmail.com       Thane
# 2  Navneet  navneetravichandran13@gmail.com  Coimbatore
# 3   Daniel          danieparera15@gmail.com       Thane

# %%
pd.read_csv('sample.csv', sep='!')
# Out:
#       Name                            Email    Location
# 0  Shreyas        shreyasbanagar7@gmail.com       Thane
# 1  Navneet  navneetravichandran13@gmail.com  Coimbatore
# 2   Daniel          danieparera15@gmail.com       Thane

# %%
df = pd.read_csv('sample.csv')

# %%
df
# Out:
#       Name                            Email    Location
# 0  Shreyas        shreyasbanagar7@gmail.com       Thane
# 1  Navneet  navneetravichandran13@gmail.com  Coimbatore
# 2   Daniel          danieparera15@gmail.com       Thane

# %%
df.dtypes
# Out:
# Name        object
# Email       object
# Location    object
# dtype: object

# %%
df = pd.read_csv('sample.csv')

# %%
df
# Out:
#       Name                            Email    Location   Phone no
# 0  Shreyas        shreyasbanagar7@gmail.com       Thane  123456789
# 1  Navneet  navneetravichandran13@gmail.com  Coimbatore  123456789
# 2   Daniel          danieparera15@gmail.com       Thane  123456789

# %%
df.dtypes
# Out:
# Name        object
# Email       object
# Location    object
# Phone no     int64
# dtype: object

# %%
df2 = pd.read_csv('sample2.csv')

# %%
df2
# Out:
#         Direction  Year        Date    Weekday Country Commodity  \
# 0         Exports  2015  01/01/2015   Thursday     All       All
# 1         Exports  2015  02/01/2015     Friday     All       All
# 2         Exports  2015  03/01/2015   Saturday     All       All
# 3         Exports  2015  04/01/2015     Sunday     All       All
# 4         Exports  2015  05/01/2015     Monday     All       All
# 5         Exports  2015  06/01/2015    Tuesday     All       All
# 6         Exports  2015  07/01/2015  Wednesday     All       All
# 7         Exports  2015  08/01/2015   Thursday     All       All
# 8         Exports  2015  09/01/2015     Friday     All       All
# 9         Exports  2015  10/01/2015   Saturday     All       All
# 10        Exports  2015  11/01/2015     Sunday     All       All
# 11        Exports  2015  12/01/2015     Monday     All       All
# 12        Exports  2015  13/01/2015    Tuesday     All       All
# ...

# %%
df2.head()
# Out:
#   Direction  Year        Date   Weekday Country Commodity Transport_Mode  \
# 0   Exports  2015  01/01/2015  Thursday     All       All            All
# 1   Exports  2015  02/01/2015    Friday     All       All            All
# 2   Exports  2015  03/01/2015  Saturday     All       All            All
# 3   Exports  2015  04/01/2015    Sunday     All       All            All
# 4   Exports  2015  05/01/2015    Monday     All       All            All
#
#   Measure      Value  Cumulative
# 0       $  104000000   104000000
# 1       $   96000000   200000000
# 2       $   61000000   262000000
# 3       $   74000000   336000000
# 4       $  105000000   442000000

# %%
df2.columns
# Out:
# Index(['Direction', 'Year', 'Date', 'Weekday', 'Country', 'Commodity',
#        'Transport_Mode', 'Measure', 'Value', 'Cumulative'],
#       dtype='object')

# %%
df2.dtypes
# Out:
# Direction         object
# Year               int64
# Date              object
# Weekday           object
# Country           object
# Commodity         object
# Transport_Mode    object
# Measure           object
# Value              int64
# Cumulative         int64
# dtype: object

# %%
a = df2['Transport_Mode']

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
b = df2[['Transport_Mode', 'Measure']]

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
b.head()
# Out:
#   Transport_Mode Measure
# 0            All       $
# 1            All       $
# 2            All       $
# 3            All       $
# 4            All       $

# %%
type(df2[['Measure']])
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is DE4E-8ADB
#
#  Directory of C:\Users\shreyas.banagar\OneDrive - Zycus\iNeuron\Repos\test-python-repo\Pandas
#
# 02/26/2022  12:59 PM    <DIR>          .
# 02/26/2022  12:59 PM    <DIR>          ..
# 02/26/2022  12:07 PM    <DIR>          .ipynb_checkpoints
# 02/26/2022  12:55 PM            56,405 pandas-first-class.ipynb
# 02/26/2022  12:38 PM               191 sample.csv
# 02/26/2022  12:40 PM         9,489,772 sample2.csv
# 02/26/2022  12:59 PM            71,993 sample3.xlsx
# 02/26/2022  12:16 PM    <DIR>          venv
#                4 File(s)      9,618,361 bytes
#                4 Dir(s)  170,953,351,168 bytes free

# %%
df = pd.read_excel('sample3.xlsx',sheet_name='Placements')

# %%
df = pd.ExcelFile('sample3.xlsx')

# %%
df.sheet_names
# Out:
# ['Orders', 'Allocations', 'Placements', 'Blocks']

# %%
for i in df.sheet_names:
    df_sample= pd.read_excel('sample3.xlsx',sheet_name=i)
    df_sample

# %%
pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...
